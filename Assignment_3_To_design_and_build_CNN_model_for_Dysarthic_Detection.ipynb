# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import re
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
from sklearn.preprocessing import minmax_scale
import IPython.display as ipd

plt.rcParams['figure.figsize'] = (20,8)
plt.rcParams['font.size'] = 16
warnings.filterwarnings("ignore")

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
import os

# Set Kaggle API credentials path
os.environ['KAGGLE_CONFIG_DIR'] = '/root/.kaggle/'

# Download the dataset
# !kaggle datasets download -d iamhungundji/dysarthria-detection

# Unzip the downloaded file
# !unzip -q '*.zip' -d data
# Out:
# Downloading dysarthria-detection.zip to /content
#  89% 138M/155M [00:01<00:00, 132MB/s]
# 100% 155M/155M [00:01<00:00, 137MB/s]

# %% [markdown]
# # Data Visualization and EDA

# %%
directory = '/content/data/dysarthria_detection'
data = pd.read_csv("/content/data/dysarthria_detection/torgo_data/data.csv")
data['filename'] = data['filename'].apply(lambda x: os.path.join(directory,x))
data
# Out:
#        is_dysarthria  gender  \
# 0     non_dysarthria  female
# 1     non_dysarthria  female
# 2     non_dysarthria  female
# 3     non_dysarthria  female
# 4     non_dysarthria  female
# ...              ...     ...
# 1995      dysarthria    male
# 1996      dysarthria    male
# 1997      dysarthria    male
# 1998      dysarthria    male
# 1999      dysarthria    male
#
#                                                filename
# 0     /content/data/dysarthria_detection/torgo_data/...
# 1     /content/data/dysarthria_detection/torgo_data/...
# 2     /content/data/dysarthria_detection/torgo_data/...
# 3     /content/data/dysarthria_detection/torgo_data/...
# 4     /content/data/dysarthria_detection/torgo_data/...
# ...                                                 ...
# 1995  /content/data/dysarthria_detection/torgo_data/...
# 1996  /content/data/dysarthria_detection/torgo_data/...
# 1997  /content/data/dysarthria_detection/torgo_data/...
# 1998  /content/data/dysarthria_detection/torgo_data/...
# 1999  /content/data/dysarthria_detection/torgo_data/...
#
# [2000 rows x 3 columns]

# %% [markdown]
# ## Functions for Visualizations

# %%
def show_waveplot(audio_path,label,gender):
    x , sr = librosa.load(audio_path)
    plt.figure(figsize=(20, 6))
    librosa.display.waveshow(x, sr=sr)
    plt.title(f"Waveplot: of Class: {label}, Gender: {gender}")

def show_spectrogram(audio_path,label,gender):
    x , sr = librosa.load(audio_path)
    X = librosa.stft(x)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(20,6))
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz',cmap='plasma')
    plt.colorbar()
    plt.title(f"Spectrogram of Class: {label}, Gender: {gender}")

def show_zcr(audio_path,label,gender):
    x , sr = librosa.load(audio_path)
    zero_crossings = librosa.zero_crossings(x)
    print("Sum of zero crossing ", zero_crossings.sum())
    plt.figure(figsize=(20, 5))
    plt.title(f'Zero Crossing Rate of Class: {label}, Gender: {gender}')
    zcrs = librosa.feature.zero_crossing_rate(x)
    plt.plot(zcrs[0])
    plt.show()

def normalize(x, axis=0):
    return minmax_scale(x, axis=axis)

def show_spectral_centroids(audio_path,label,gender):
    plt.figure(figsize=(20, 5))
    plt.title(f'Spectral Centroids of Class: {label}, Gender: {gender}')
    x , sr = librosa.load(audio_path)
    spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)[0]
    frames = range(len(spectral_centroids))
    t = librosa.frames_to_time(frames)
    librosa.display.waveshow(x, sr=sr, alpha=0.4)
    plt.plot(t, normalize(spectral_centroids), color='r')
    plt.show()

def show_spectral_rolloff(audio_path,label,gender):
    plt.figure(figsize=(20, 5))
    plt.title(f'Spectral Rolloff of Class: {label}, Gender: {gender}')
    x , sr = librosa.load(audio_path)
    spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr, roll_percent=0.01)[0]
    frames = range(len(spectral_rolloff))
    t = librosa.frames_to_time(frames)
    librosa.display.waveshow(x, sr=sr, alpha=0.4)
    plt.plot(t, normalize(spectral_rolloff), color='r')
    plt.show()

def show_mfccs(audio_path,label,gender):
    plt.figure(figsize=(20, 6))
    plt.title(f'MFCC of Class: {label}, Gender: {gender}')
    x , sr = librosa.load(audio_path)
    mfccs = librosa.feature.mfcc(y=x, sr=sr)
    librosa.display.specshow(mfccs, sr=sr, x_axis='time',cmap='plasma')
    plt.show()

def show_melspectro(audio_path,label,gender):
    plt.figure(figsize=(20, 6))
    plt.title(f'Mel Spectro of Class: {label}, Gender: {gender}')
    x , sr = librosa.load(audio_path)
    melspectro = librosa.feature.melspectrogram(y=x, sr=sr)
    librosa.display.specshow(melspectro, sr=sr, x_axis='time',cmap='plasma')
    plt.show()

# %%
data.sample(frac=1).reset_index(drop=True,inplace=True)
male_dysarthric = data[(data['gender']=='male') & (data['is_dysarthria']=='dysarthria')].sample(1)
female_dysarthric = data[(data['gender']=='female') & (data['is_dysarthria']=='dysarthria')].sample(1)
male_ndysarthric = data[(data['gender']=='male') & (data['is_dysarthria']=='non_dysarthria')].sample(1)
female_ndysarthric = data[(data['gender']=='female') & (data['is_dysarthria']=='non_dysarthria')].sample(1)

# %% [markdown]
# ## Male and Dysarthric

# %%
ipd.Audio(male_dysarthric.iloc[0].filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Female and Dysarthric

# %%
ipd.Audio(female_dysarthric.iloc[0].filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Male and Non Dysarthric

# %%
ipd.Audio(male_ndysarthric.iloc[0].filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Female and Dysarthric

# %%
ipd.Audio(female_ndysarthric.iloc[0].filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Waveplots

# %%
show_waveplot(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_waveplot(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_waveplot(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_waveplot(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)

# %% [markdown]
# ## Spectrograms

# %%
show_spectrogram(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_spectrogram(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_spectrogram(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_spectrogram(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)

# %% [markdown]
# ## Zero Crossing Rate
# -

# %%
show_zcr(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_zcr(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_zcr(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_zcr(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)
# Out:
# Sum of zero crossing  3394
# Sum of zero crossing  4121
# Sum of zero crossing  2469
# Sum of zero crossing  8265

# %% [markdown]
# ## Spectral Centroid

# %%
show_spectral_centroids(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_spectral_centroids(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_spectral_centroids(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_spectral_centroids(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-74ef457c66f8> in <cell line: 1>()
# ----> 1 show_spectral_centroids(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
#       2 show_spectral_centroids(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
#       3 show_spectral_centroids(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
#       4 show_spectral_centroids(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)
#
# <ipython-input-5-302852806e0d> in show_spectral_centroids(audio_path, label, gender)
#      31     plt.title(f'Spectral Centroids of Class: {label}, Gender: {gender}')
#      32     x , sr = librosa.load(audio_path)
# ---> 33     spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)[0]
#      34     frames = range(len(spectral_centroids))
#      35     t = librosa.frames_to_time(frames)
#
# TypeError: spectral_centroid() takes 0 positional arguments but 1 positional argument (and 1 keyword-only argument) were given

# %% [markdown]
# ## Spectral Rolloff

# %%
show_spectral_rolloff(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_spectral_rolloff(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_spectral_rolloff(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_spectral_rolloff(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-95184a728d98> in <cell line: 1>()
# ----> 1 show_spectral_rolloff(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
#       2 show_spectral_rolloff(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
#       3 show_spectral_rolloff(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
#       4 show_spectral_rolloff(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)
#
# <ipython-input-5-302852806e0d> in show_spectral_rolloff(audio_path, label, gender)
#      42     plt.title(f'Spectral Rolloff of Class: {label}, Gender: {gender}')
#      43     x , sr = librosa.load(audio_path)
# ---> 44     spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr, roll_percent=0.01)[0]
#      45     frames = range(len(spectral_rolloff))
#      46     t = librosa.frames_to_time(frames)
#
# TypeError: spectral_rolloff() takes 0 positional arguments but 1 positional argument (and 2 keyword-only arguments) were given

# %% [markdown]
# ## MFCCs

# %%
show_mfccs(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_mfccs(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_mfccs(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_mfccs(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)

# %% [markdown]
# ## Mel Spectrogram

# %%
show_melspectro(male_dysarthric.iloc[0].filename, male_dysarthric.iloc[0].is_dysarthria, male_dysarthric.iloc[0].gender)
show_melspectro(female_dysarthric.iloc[0].filename, female_dysarthric.iloc[0].is_dysarthria, female_dysarthric.iloc[0].gender)
show_melspectro(male_ndysarthric.iloc[0].filename, male_ndysarthric.iloc[0].is_dysarthria, male_ndysarthric.iloc[0].gender)
show_melspectro(female_ndysarthric.iloc[0].filename, female_ndysarthric.iloc[0].is_dysarthria, female_ndysarthric.iloc[0].gender)

# %% [markdown]
# # Feature Extraction
# - Extracts 128 MFCC Features, which was the maximum possible features during the extraction process

# %%
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, recall_score

# %%
def feature_extraction(df):
    features = []
    for i,record in tqdm(df.iterrows(),total=df.shape[0]):
        try:
            x , sr = librosa.load(record['filename'])
            mean_mfcc = np.mean(librosa.feature.mfcc(y=x, sr=sr, n_mfcc=128),axis=1)
            features.append(mean_mfcc)
        except EOFError:
            pass

    dataf = pd.DataFrame(features)
    dataf['class'] = df['is_dysarthria']
    return dataf

# %%
dataf = feature_extraction(data)
# Out:
# 100%|██████████| 2000/2000 [00:48<00:00, 41.27it/s]

# %%
dataf
# Out:
#                0           1          2          3          4          5  \
# 0    -221.788269  101.259232 -16.548132  38.492065 -13.595653  20.772554
# 1    -299.520081  109.872574 -17.097269  38.854969 -16.881130  22.959133
# 2    -302.950043  112.048477 -23.679882  44.887413 -22.434727  26.299335
# 3    -210.861603  116.504486 -35.046494  37.670425 -27.112516  25.593727
# 4    -280.227203  104.505035 -17.209877  45.064884 -15.542122  28.115068
# ...          ...         ...        ...        ...        ...        ...
# 1994 -304.231995  115.359306  -0.794746  26.543352  -0.682190  13.183387
# 1995 -457.822144  110.087799  22.221985  -0.056086 -11.181323   3.190089
# 1996 -371.546875  116.846909   5.667272  22.488144   8.221014   7.740131
# 1997 -302.500702  112.511192  -4.506540  32.498363  -1.519380   4.109807
# 1998 -385.800110   96.079300   8.155581  31.456228  -5.310203  17.052404
#
#              6          7         8         9  ...       119       120  \
# 0    -5.536349  10.410690  1.962461 -0.799047  ...  0.962193  0.744855
# 1     1.824228  18.724188  3.448541  4.455822  ...  1.105589  1.056284
# 2     0.811477  18.210291  4.344697  4.912156  ...  0.844332  0.530004
# 3    -7.511986  13.140750 -0.587347  4.138087  ...  0.630752  0.898457
# 4    -3.449209  16.841436  4.573242  1.738296  ...  1.596206  0.970084
# ...        ...        ...       ...       ...  ...       ...       ...
# 1994  2.389222   4.290236 -1.372811 -2.624718  ...  0.473923  0.103740
# 1995 -4.499060   4.474746  5.809545 -1.913331  ...  0.622933  0.508349
# 1996  8.989120   9.996635  4.383992  3.590931  ...  0.240280 -0.009779
# 1997  4.611475   9.744307 -2.962905 -3.497744  ...  0.146675 -0.200982
# 1998  8.346518  12.127321  3.636643  0.342048  ...  0.865302  0.567675
#
#            121       122       123       124       125       126       127  \
# 0     1.058080  0.388451  0.081758  0.546172  0.594357  0.170033 -0.219215
# 1     1.252576  0.027333 -1.368948 -0.037859  0.020661 -0.082124 -0.744832
# 2     1.018391  0.055385 -1.472088  0.295324  0.191228 -0.224301 -0.582725
# 3     0.721398  0.174576 -0.090706  0.001524  0.360464 -0.075448 -0.259715
# 4     0.732015  0.547593 -0.152664  0.131893 -0.288228 -0.468570 -0.461726
# ...        ...       ...       ...       ...       ...       ...       ...
# 1994  0.311737  0.015566 -0.055351  0.193023  0.332826  0.014455 -0.221991
# 1995  0.398737  0.455839  0.348571  0.286893  0.150862 -0.052999  0.001199
# 1996 -0.018253 -0.014393 -0.263360  0.556257  0.749682 -0.283888 -0.398581
# 1997  0.388719  0.160434 -0.383473  0.417755  1.042827 -0.082762 -0.111990
# 1998  0.632113  0.017563 -0.279238  0.666378  0.482809 -0.240434 -0.301907
#
#                class
# 0     non_dysarthria
# 1     non_dysarthria
# 2     non_dysarthria
# 3     non_dysarthria
# 4     non_dysarthria
# ...              ...
# 1994      dysarthria
# 1995      dysarthria
# 1996      dysarthria
# 1997      dysarthria
# 1998      dysarthria
#
# [1999 rows x 129 columns]

# %%
dataf.loc[dataf['class']=='non_dysarthria','class'] = 0.0
dataf.loc[dataf['class']=='dysarthria','class'] = 1.0
dataf['class'] = dataf['class'].astype(float)

X = dataf.iloc[:,:-1].values
y = dataf.iloc[:,-1]

# %%
X.shape, y.shape
# Out:
# ((1999, 128), (1999,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y)
X_train = X_train.reshape(-1,16,8,1)
X_test = X_test.reshape(-1,16,8,1)

# %% [markdown]
# # Modelling

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential([
    InputLayer(input_shape=(16, 8, 1)),
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding = "same"),
    MaxPooling2D(2, 2),
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding = "same"),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 8, 32)         320
#
#  max_pooling2d (MaxPooling2D  (None, 8, 4, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 4, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 32)                16416
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 35,265
# Trainable params: 35,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_name = "model.h5"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=1)

earlystopping = EarlyStopping(monitor='val_loss',min_delta = 0, patience = 5, verbose = 1, restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test,y_test), callbacks=[checkpoint,earlystopping])
# Out:
# Epoch 1/50
# 53/57 [==========================>...] - ETA: 0s - loss: 0.6005 - accuracy: 0.7134
# Epoch 1: val_loss improved from inf to 0.42711, saving model to model.h5
# 57/57 [==============================] - 3s 25ms/step - loss: 0.5914 - accuracy: 0.7165 - val_loss: 0.4271 - val_accuracy: 0.8050
# Epoch 2/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.3685 - accuracy: 0.8358
# Epoch 2: val_loss improved from 0.42711 to 0.32193, saving model to model.h5
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3699 - accuracy: 0.8355 - val_loss: 0.3219 - val_accuracy: 0.8550
# Epoch 3/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.2439 - accuracy: 0.9096
# Epoch 3: val_loss improved from 0.32193 to 0.18159, saving model to model.h5
# 57/57 [==============================] - 1s 15ms/step - loss: 0.2435 - accuracy: 0.9094 - val_loss: 0.1816 - val_accuracy: 0.9250
# Epoch 4/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.1730 - accuracy: 0.9387
# Epoch 4: val_loss improved from 0.18159 to 0.14879, saving model to model.h5
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1704 - accuracy: 0.9405 - val_loss: 0.1488 - val_accuracy: 0.9350
# Epoch 5/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.1238 - accuracy: 0.9659
# Epoch 5: val_loss improved from 0.14879 to 0.10984, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 0.1223 - accuracy: 0.9666 - val_loss: 0.1098 - val_accuracy: 0.9750
# Epoch 6/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.1047 - accuracy: 0.9606
# Epoch 6: val_loss improved from 0.10984 to 0.10894, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 0.1073 - accuracy: 0.9600 - val_loss: 0.1089 - val_accuracy: 0.9600
# Epoch 7/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9704
# Epoch 7: val_loss improved from 0.10894 to 0.06337, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0909 - accuracy: 0.9700 - val_loss: 0.0634 - val_accuracy: 0.9900
# Epoch 8/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0801 - accuracy: 0.9773
# Epoch 8: val_loss improved from 0.06337 to 0.05120, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0793 - accuracy: 0.9778 - val_loss: 0.0512 - val_accuracy: 0.9950
# Epoch 9/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0464 - accuracy: 0.9896
# Epoch 9: val_loss improved from 0.05120 to 0.04621, saving model to model.h5
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0467 - accuracy: 0.9889 - val_loss: 0.0462 - val_accuracy: 0.9950
# Epoch 10/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9911
# Epoch 10: val_loss did not improve from 0.04621
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0387 - accuracy: 0.9911 - val_loss: 0.0518 - val_accuracy: 0.9900
# Epoch 11/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0304 - accuracy: 0.9936
# Epoch 11: val_loss improved from 0.04621 to 0.03155, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0306 - accuracy: 0.9933 - val_loss: 0.0316 - val_accuracy: 0.9950
# Epoch 12/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0300 - accuracy: 0.9936
# Epoch 12: val_loss did not improve from 0.03155
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0294 - accuracy: 0.9939 - val_loss: 0.0397 - val_accuracy: 0.9900
# Epoch 13/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0209 - accuracy: 0.9959
# Epoch 13: val_loss did not improve from 0.03155
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0231 - accuracy: 0.9956 - val_loss: 0.0324 - val_accuracy: 0.9900
# Epoch 14/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9989
# Epoch 14: val_loss improved from 0.03155 to 0.02729, saving model to model.h5
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0170 - accuracy: 0.9989 - val_loss: 0.0273 - val_accuracy: 0.9900
# Epoch 15/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0148 - accuracy: 0.9977
# Epoch 15: val_loss did not improve from 0.02729
# 57/57 [==============================] - 1s 21ms/step - loss: 0.0159 - accuracy: 0.9972 - val_loss: 0.0397 - val_accuracy: 0.9900
# Epoch 16/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9967
# Epoch 16: val_loss improved from 0.02729 to 0.02626, saving model to model.h5
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0207 - accuracy: 0.9967 - val_loss: 0.0263 - val_accuracy: 0.9900
# Epoch 17/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0131 - accuracy: 0.9961
# Epoch 17: val_loss did not improve from 0.02626
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0273 - val_accuracy: 0.9850
# Epoch 18/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0123 - accuracy: 0.9983
# Epoch 18: val_loss did not improve from 0.02626
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0343 - val_accuracy: 0.9900
# Epoch 19/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0123 - accuracy: 0.9960
# Epoch 19: val_loss improved from 0.02626 to 0.02346, saving model to model.h5
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.0235 - val_accuracy: 0.9950
# Epoch 20/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0108 - accuracy: 0.9971
# Epoch 20: val_loss did not improve from 0.02346
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0314 - val_accuracy: 0.9850
# Epoch 21/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0081 - accuracy: 0.9994
# Epoch 21: val_loss did not improve from 0.02346
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.0261 - val_accuracy: 0.9850
# Epoch 22/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9994
# Epoch 22: val_loss did not improve from 0.02346
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.0300 - val_accuracy: 0.9850
# Epoch 23/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0052 - accuracy: 0.9994
# Epoch 23: val_loss improved from 0.02346 to 0.01672, saving model to model.h5
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0167 - val_accuracy: 0.9950
# Epoch 24/50
# 53/57 [==========================>...] - ETA: 0s - loss: 0.0074 - accuracy: 0.9988
# Epoch 24: val_loss improved from 0.01672 to 0.01368, saving model to model.h5
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0077 - accuracy: 0.9989 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 25/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0207 - accuracy: 0.9931
# Epoch 25: val_loss did not improve from 0.01368
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.0393 - val_accuracy: 0.9850
# Epoch 26/50
# 53/57 [==========================>...] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.01368
# 57/57 [==============================] - 1s 12ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9950
# Epoch 27/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9989
# Epoch 27: val_loss did not improve from 0.01368
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0056 - accuracy: 0.9989 - val_loss: 0.0170 - val_accuracy: 0.9950
# Epoch 28/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.01368 to 0.01318, saving model to model.h5
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 29/50
# 56/57 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.01318
# 57/57 [==============================] - 1s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9950
# Epoch 30/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.01318 to 0.01317, saving model to model.h5
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9950
# Epoch 31/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0093 - accuracy: 0.9977
# Epoch 31: val_loss improved from 0.01317 to 0.01076, saving model to model.h5
# 57/57 [==============================] - 1s 21ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0108 - val_accuracy: 0.9950
# Epoch 32/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0556 - accuracy: 0.9807
# Epoch 32: val_loss did not improve from 0.01076
# 57/57 [==============================] - 1s 17ms/step - loss: 0.0548 - accuracy: 0.9811 - val_loss: 0.0143 - val_accuracy: 0.9950
# Epoch 33/50
# 55/57 [===========================>..] - ETA: 0s - loss: 0.0109 - accuracy: 0.9972
# Epoch 33: val_loss did not improve from 0.01076
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.0528 - val_accuracy: 0.9750
# Epoch 34/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0525 - accuracy: 0.9763
# Epoch 34: val_loss did not improve from 0.01076
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0511 - accuracy: 0.9767 - val_loss: 0.0342 - val_accuracy: 0.9850
# Epoch 35/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0076 - accuracy: 0.9971
# Epoch 35: val_loss did not improve from 0.01076
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.0111 - val_accuracy: 0.9950
# Epoch 36/50
# 54/57 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.01076 to 0.00762, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 37/50
# 53/57 [==========================>...] - ETA: 0s - loss: 7.6275e-04 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.00762
# 57/57 [==============================] - 1s 13ms/step - loss: 7.5997e-04 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 38/50
# 54/57 [===========================>..] - ETA: 0s - loss: 6.8218e-04 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.00762
# 57/57 [==============================] - 1s 13ms/step - loss: 6.8675e-04 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9900
# Epoch 39/50
# 55/57 [===========================>..] - ETA: 0s - loss: 5.8375e-04 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.00762
# 57/57 [==============================] - 1s 12ms/step - loss: 5.7814e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9900
# Epoch 40/50
# 53/57 [==========================>...] - ETA: 0s - loss: 5.2359e-04 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00762 to 0.00745, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 5.5642e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 41/50
# 57/57 [==============================] - ETA: 0s - loss: 5.5203e-04 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00745
# 57/57 [==============================] - 1s 13ms/step - loss: 5.5203e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9950
# Epoch 42/50
# 57/57 [==============================] - ETA: 0s - loss: 4.9470e-04 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00745
# 57/57 [==============================] - 1s 13ms/step - loss: 4.9470e-04 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 43/50
# 56/57 [============================>.] - ETA: 0s - loss: 4.3971e-04 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00745
# 57/57 [==============================] - 1s 14ms/step - loss: 4.3846e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 44/50
# 55/57 [===========================>..] - ETA: 0s - loss: 4.2034e-04 - accuracy: 1.0000
# Epoch 44: val_loss improved from 0.00745 to 0.00525, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 4.1544e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 45/50
# 54/57 [===========================>..] - ETA: 0s - loss: 4.7396e-04 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.00525 to 0.00481, saving model to model.h5
# 57/57 [==============================] - 1s 17ms/step - loss: 4.6225e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 46/50
# 56/57 [============================>.] - ETA: 0s - loss: 3.6308e-04 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00481
# 57/57 [==============================] - 1s 19ms/step - loss: 3.6207e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9950
# Epoch 47/50
# 56/57 [============================>.] - ETA: 0s - loss: 3.4339e-04 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00481
# 57/57 [==============================] - 1s 19ms/step - loss: 3.4240e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 48/50
# 56/57 [============================>.] - ETA: 0s - loss: 3.2418e-04 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.00481
# 57/57 [==============================] - 1s 15ms/step - loss: 3.2296e-04 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9950
# Epoch 49/50
# 55/57 [===========================>..] - ETA: 0s - loss: 3.0970e-04 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.00481 to 0.00480, saving model to model.h5
# 57/57 [==============================] - 1s 13ms/step - loss: 3.1209e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 50/50
# 54/57 [===========================>..] - ETA: 0s - loss: 2.8354e-04 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00480
# 57/57 [==============================] - 1s 12ms/step - loss: 2.8769e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000

# %% [markdown]
# # Model Summary

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 5ms/step

# %% [markdown]
# ## ROC Curve and AUC Score

# %%
plt.figure(figsize=(20,8))
fpr, tpr, _ = roc_curve(y_test,  y_pred)
auc = roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="CNN Model, auc="+str(auc),lw=2)
plt.plot([0, 1], [0, 1], color="orange", lw=2, linestyle="--")
plt.legend(loc=4)
plt.show()

# %%
y_pred[y_pred>=0.5] = 1
y_pred[y_pred<0.5] = 0

# %% [markdown]
# # Confusion Matrix

# %%
sns.heatmap(confusion_matrix(y_test, y_pred),cmap='viridis',annot=True,fmt='.3g',
            xticklabels=['Non Dysarthria','Dysarthria'],yticklabels=['Non Dysarthria','Dysarthria'])
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.show()

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       100
#          1.0       1.00      1.00      1.00       100
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
print("Recall Score of the Model: ",recall_score(y_test,y_pred))
# Out:
# Recall Score of the Model:  1.0
